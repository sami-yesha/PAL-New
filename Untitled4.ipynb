# %%
import google.generativeai as genai
import os

# Set up your API key
os.environ["GEMINI_API_KEY"] = "AIzaSyBJ1eZFD2mYbKC1ICvl07MclzRb980quYk"
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# Define the model
model = genai.GenerativeModel('gemini-1.5-flash')

def solve_word_problem(word_problem):
    """Solve a given word problem using structured reasoning with the language model."""

    # Step 1: Generate structured reasoning steps
    reasoning_prompt = f"Break down the steps to solve this word problem in detail: {word_problem}"
    structured_steps = model.generate_content(reasoning_prompt)
    print(f"Intermediate structured reasoning steps:\n{structured_steps.text}\n")

    # Step 2: Modify the structured steps (optional)
    modified_steps = modify_reasoning_steps(structured_steps.text)

    # Step 3: Re-feed the modified steps into the LLM for the final result
    final_prompt = f"Now solve the problem based on the modified steps: {modified_steps}"
    final_solution = model.generate_content(final_prompt)

    # Output the final result
    print(f"Final Solution: {final_solution.text}\n")

# %%
def modify_reasoning_steps(steps):
    """Modify the generated reasoning steps for improved clarity or complexity."""
    # Example modification - can add complexity or clarity
    modified_steps = f"""
1. Review the problem statement and identify key variables.
2. Use the formula for speed: speed = distance / time.
3. Assign values: Distance = 100 miles, Time = 2 hours.
4. Check for any units inconsistency (none in this case).
5. Perform the calculation:
   - Step A: Calculate the distance divided by time: 100 miles / 2 hours.
   - Step B: Ensure all units are consistent; speed = 50 miles per hour.
"""
    return modified_steps

# Example word problems
word_problems = [
    "If a train travels 100 miles in 2 hours, what is its average speed?",
    "A car covers 240 miles in 3 hours. How fast is it moving?",
    "If a cyclist rides at a speed of 15 miles per hour for 4 hours, how far does he travel?"
]

# Solve each word problem
for problem in word_problems:
    solve_word_problem(problem)
# Out:
# Intermediate structured reasoning steps:
# Here's how to break down the problem:
#
# **1. Understand the Concept of Speed:**
#
# * **Speed** is a measure of how fast something is moving.  It's calculated by dividing the distance traveled by the time it takes to travel that distance.
#
# **2. Identify the Given Information:**
#
# * **Distance:** 100 miles
# * **Time:** 2 hours
#
# **3. Apply the Formula:**
#
# * **Speed = Distance / Time**
#
# **4. Substitute the Values:**
#
# * Speed = 100 miles / 2 hours
#
# **5. Calculate the Result:**
#
# * Speed = 50 miles per hour (mph)
#
# **Therefore, the train's average speed is 50 mph.**
#
#
# Final Solution: The problem statement is not provided. However, based on the given steps, we can assume it's a problem about calculating speed.
#
# Let's follow the steps:
#
# **1. Review the problem statement and identify key variables.**
# * **Problem Statement:** We need a problem statement to identify the key variables.
#
# ...
